# %% [markdown]
# ### Assignment 1

# %% [markdown]
# a) Find Shape of Data
# b) Find Missing Values
# c) Find data type of each column
# d) Finding out Zero's
# e) Find Mean age of patients
# f) Now extract only Age, Sex, ChestPain, RestBP, Chol.
# Randomly divide the dataset in training (75%) and testing (25%). Through
# the diagnosis test I predicted 100 reports as COVID positive, but only 45 of
# those were actually positive. Total 50 people in my sample were actually
# COVID positive. I have a total of 500 samples.
# Create a confusion matrix based on the above data and find I. Accuracy II.
# Precision III. Recall IV. F-1 score

# %%
import numpy as np
import pandas as pd

# %%
# read cvs file file in pandas
df = pd.read_csv('./datasets/wine-clustering.csv')

# %%
df.head(2)
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
#
#    OD280  Proline
# 0   3.92     1065
# 1   3.40     1050

# %%
 # a ) find shape of data 
df.shape
# Out:
# (178, 13)

# %%
# b) find missing values 

df.isnull().sum()
# Out:
# Alcohol                 0
# Malic_Acid              0
# Ash                     0
# Ash_Alcanity            0
# Magnesium               0
# Total_Phenols           0
# Flavanoids              0
# Nonflavanoid_Phenols    0
# Proanthocyanins         0
# Color_Intensity         0
# Hue                     0
# OD280                   0
# Proline                 0
# dtype: int64

# %%
# c) find data type of each column 

df.dtypes
# Out:
# Alcohol                 float64
# Malic_Acid              float64
# Ash                     float64
# Ash_Alcanity            float64
# Magnesium                 int64
# Total_Phenols           float64
# Flavanoids              float64
# Nonflavanoid_Phenols    float64
# Proanthocyanins         float64
# Color_Intensity         float64
# Hue                     float64
# OD280                   float64
# Proline                   int64
# dtype: object

# %%
# find the no of zeros 
num_zeros = (df == 0).sum().sum()

num_zeros
# Out:
# np.int64(1)

# %%
df.describe()
# Out:
#           Alcohol  Malic_Acid         Ash  Ash_Alcanity   Magnesium  \
# count  178.000000  178.000000  178.000000    178.000000  178.000000
# mean    13.000618    2.336348    2.366517     19.494944   99.741573
# std      0.811827    1.117146    0.274344      3.339564   14.282484
# min     11.030000    0.740000    1.360000     10.600000   70.000000
# 25%     12.362500    1.602500    2.210000     17.200000   88.000000
# 50%     13.050000    1.865000    2.360000     19.500000   98.000000
# 75%     13.677500    3.082500    2.557500     21.500000  107.000000
# max     14.830000    5.800000    3.230000     30.000000  162.000000
#
#        Total_Phenols  Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Alcohol               178 non-null    float64
#  1   Malic_Acid            178 non-null    float64
#  2   Ash                   178 non-null    float64
#  3   Ash_Alcanity          178 non-null    float64
#  4   Magnesium             178 non-null    int64
#  5   Total_Phenols         178 non-null    float64
#  6   Flavanoids            178 non-null    float64
#  7   Nonflavanoid_Phenols  178 non-null    float64
#  8   Proanthocyanins       178 non-null    float64
#  9   Color_Intensity       178 non-null    float64
#  10  Hue                   178 non-null    float64
#  11  OD280                 178 non-null    float64
#  12  Proline               178 non-null    int64
# dtypes: float64(11), int64(2)
# memory usage: 18.2 KB

# %%
#selects the 1st row
df.iloc[3]
# Out:
# Alcohol                   14.37
# Malic_Acid                 1.95
# Ash                        2.50
# Ash_Alcanity              16.80
# Magnesium                113.00
# Total_Phenols              3.85
# Flavanoids                 3.49
# Nonflavanoid_Phenols       0.24
# Proanthocyanins            2.18
# Color_Intensity            7.80
# Hue                        0.86
# OD280                      3.45
# Proline                 1480.00
# Name: 3, dtype: float64

# %%
# select 3 to 8 rows 
df.iloc[3:9]
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
# 5    14.20        1.76  2.45          15.2        112           3.27
# 6    14.39        1.87  2.45          14.6         96           2.50
# 7    14.06        2.15  2.61          17.6        121           2.60
# 8    14.83        1.64  2.17          14.0         97           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
# 5        3.39                  0.34             1.97             6.75  1.05
# 6        2.52                  0.30             1.98             5.25  1.02
# 7        2.51                  0.31             1.25             5.05  1.06
# ...

# %%
df[['Alcohol','Magnesium','Color_Intensity']].head(4)
# Out:
#    Alcohol  Magnesium  Color_Intensity
# 0    14.23        127             5.64
# 1    13.20        100             4.38
# 2    13.16        101             5.68
# 3    14.37        113             7.80

# %%
# sort data by alcohol content

sorted = df.sort_values(by='Alcohol',ascending=True)
sorted
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 115    11.03        1.51  2.20          21.5         85           2.46
# 113    11.41        0.74  2.50          21.0         88           2.48
# 120    11.45        2.40  2.42          20.0         96           2.90
# 110    11.46        3.74  1.82          19.5        107           3.18
# 121    11.56        2.05  3.23          28.5        119           3.18
# ..       ...         ...   ...           ...        ...            ...
# 14     14.38        1.87  2.38          12.0        102           3.30
# 46     14.38        3.59  2.28          16.0        102           3.25
# 6      14.39        1.87  2.45          14.6         96           2.50
# 13     14.75        1.73  2.39          11.4         91           3.10
# 8      14.83        1.64  2.17          14.0         97           2.80
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %%
# unique values of Malic_Acid

df['Malic_Acid'].value_counts()
# Out:
# Malic_Acid
# 1.73    7
# 1.81    4
# 1.67    4
# 1.35    3
# 1.90    3
#        ..
# 2.51    1
# 5.65    1
# 3.91    1
# 4.28    1
# 4.10    1
# Name: count, Length: 133, dtype: int64
